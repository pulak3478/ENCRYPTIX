# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Load the dataset
file_path = ('/content/drive/MyDrive/creditcard.csv')
data = pd.read_csv(file_path)

# Display the first few rows of the dataset
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
 data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
 data.shape
# Out:
# (284807, 31)

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 1081

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
data['Class'].value_counts().plot(kind='pie', autopct="%1.1f%%", labels=['legal', 'Fraudulent'])
plt.ylabel("")
plt.title("Distribution of legal and Fraudulent Transactions")
plt.show()

# %%
fraud = data[data['Class']==1]
legal = data[data['Class']==0]
legal
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
fraud
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
legal.Amount.describe()
# Out:
# count    283253.000000
# mean         88.413575
# std         250.379023
# min           0.000000
# 25%           5.670000
# 50%          22.000000
# 75%          77.460000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     473.000000
# mean      123.871860
# std       260.211041
# min         0.000000
# 25%         1.000000
# 50%         9.820000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94835.058093  0.013439 -0.009829  0.012853 -0.010440  0.006769
# 1      80450.513742 -4.498280  3.405965 -6.729599  4.472591 -2.957197
#
#              V6        V7        V8        V9  ...       V20      V21  \
# Class                                          ...
# 0      0.001251  0.010447 -0.002448  0.002613  ... -0.000489 -0.00115
# 1     -1.432518 -5.175912  0.953255 -2.522124  ...  0.405043  0.46655
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000160  0.000360  0.000393 -0.000301  0.000065  0.001409  0.000418
# 1      0.086639 -0.096464 -0.106643  0.040615  0.050456  0.213774  0.078270
#
#            Amount
# Class
# 0       88.413575
# 1      123.871860
#
# [2 rows x 30 columns]

# %%
legal_sample = legal.sample(n=492)

# %%
new_data=pd.concat([legal_sample,fraud],axis=0)
new_data.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 244392  152329.0  1.479704 -0.862670 -1.947644  0.740769 -0.344341 -1.271976
# 65932    51807.0 -2.157377 -1.576772  0.522448 -1.762070 -1.468465 -0.342101
# 98762    66804.0  1.276741  0.310735  0.397456  1.034042 -0.079842 -0.241526
# 274440  166010.0 -0.692673  1.633894 -0.229088  0.441192  1.074831 -1.182313
# 259652  159215.0 -1.599214  1.193236  0.049224 -1.220007  0.149267  1.683521
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 244392  0.432256 -0.303750  1.150307  ... -0.097077 -0.695722 -0.047420
# 65932   0.491829  0.301149  1.472920  ...  0.326805  0.944340 -0.164028
# 98762  -0.066142 -0.080771  0.126668  ... -0.130353 -0.328005 -0.072620
# 274440  1.544179 -0.314440 -1.080334  ...  0.246188  0.731113 -0.377221
# 259652 -0.809123  1.577292  0.302176  ...  0.044139 -0.037481  0.112509
#
# ...

# %%
new_data.shape
# Out:
# (965, 31)

# %%
new_data['Class'].value_counts().plot(kind='pie', autopct="%1.1f%%", labels=['legal', 'Fraudulent'])
plt.ylabel("")
plt.title("Distribution of legal and Fraudulent Transactions")
plt.show()

# %%
data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94835.058093  0.013439 -0.009829  0.012853 -0.010440  0.006769
# 1      80450.513742 -4.498280  3.405965 -6.729599  4.472591 -2.957197
#
#              V6        V7        V8        V9  ...       V20      V21  \
# Class                                          ...
# 0      0.001251  0.010447 -0.002448  0.002613  ... -0.000489 -0.00115
# 1     -1.432518 -5.175912  0.953255 -2.522124  ...  0.405043  0.46655
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000160  0.000360  0.000393 -0.000301  0.000065  0.001409  0.000418
# 1      0.086639 -0.096464 -0.106643  0.040615  0.050456  0.213774  0.078270
#
#            Amount
# Class
# 0       88.413575
# 1      123.871860
#
# [2 rows x 30 columns]

# %%
plt.figure(figsize=(27,19))
sns.heatmap(new_data.corr(), cmap = 'coolwarm', annot= True )
plt.show()

# %%
x = new_data.drop(columns='Class',axis=1)
y = new_data['Class']
x
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 244392  152329.0  1.479704 -0.862670 -1.947644  0.740769 -0.344341 -1.271976
# 65932    51807.0 -2.157377 -1.576772  0.522448 -1.762070 -1.468465 -0.342101
# 98762    66804.0  1.276741  0.310735  0.397456  1.034042 -0.079842 -0.241526
# 274440  166010.0 -0.692673  1.633894 -0.229088  0.441192  1.074831 -1.182313
# 259652  159215.0 -1.599214  1.193236  0.049224 -1.220007  0.149267  1.683521
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
y
# Out:
# 244392    0
# 65932     0
# 98762     0
# 274440    0
# 259652    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 965, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.3,stratify=y,random_state=16)
model= LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_train_pred = model.predict(x_train)
training_data_accuracy = accuracy_score(y_train_pred,y_train)
print("Accuracy of training data:", training_data_accuracy*100,"%")
# Out:
# Accuracy of training data: 93.77777777777779 %

# %%
y_test_pred = model.predict(x_test)
test_data_accuracy = accuracy_score(y_test_pred,y_test)
print("Accuracy of test data:", test_data_accuracy*100,"%")
# Out:
# Accuracy of test data: 92.06896551724138 %

# %%
print(confusion_matrix(y_test,y_test_pred))
# Out:
# [[138  10]
#  [ 13 129]]

# %%
colors = ['#1f77b4', '#ff7f0e']
sns.barplot(y=[training_data_accuracy * 100, test_data_accuracy * 100], x=['Train Data Accuracy', 'Test Data Accuracy'], palette=colors)
plt.title("Accuracy of Train and Test Data")
plt.ylim(80, 100)
plt.xlabel("Data Type")
plt.ylabel("Accuracy Percentage")
plt.show()
# Out:
# <ipython-input-37-aa29ed271f54>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=[training_data_accuracy * 100, test_data_accuracy * 100], x=['Train Data Accuracy', 'Test Data Accuracy'], palette=colors)

# %%
print("Classification report:\n",classification_report(y_test,y_test_pred))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92       148
#            1       0.93      0.91      0.92       142
#
#     accuracy                           0.92       290
#    macro avg       0.92      0.92      0.92       290
# weighted avg       0.92      0.92      0.92       290

# %% [markdown]
# ***Conclusion:***
#
#
# **Accuracy Score of training data 93.78 %**
#
# **Accuracy score of testing data 92.06 %**
